# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df1=pd.read_csv('/content/drive/MyDrive/Tenx/Week 8/Data/Fraud_Data.csv')

# %%
df2=pd.read_csv('/content/drive/MyDrive/Tenx/Week 8/Data/IpAddress_to_Country.csv')

# %%
zip='/content/drive/My Drive/Tenx/Week 8/Data/creditcard.csv.zip'
df3=pd.read_csv(zip,compression ="zip",on_bad_lines='skip',sep=',',engine='python')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151112 entries, 0 to 151111
# Data columns (total 11 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   user_id         151112 non-null  int64
#  1   signup_time     151112 non-null  object
#  2   purchase_time   151112 non-null  object
#  3   purchase_value  151112 non-null  int64
#  4   device_id       151112 non-null  object
#  5   source          151112 non-null  object
#  6   browser         151112 non-null  object
#  7   sex             151112 non-null  object
#  8   age             151112 non-null  int64
#  9   ip_address      151112 non-null  float64
#  10  class           151112 non-null  int64
# dtypes: float64(1), int64(4), object(6)
# memory usage: 12.7+ MB

# %%
df1.head()
# Out:
#    user_id          signup_time        purchase_time  purchase_value  \
# 0    22058  2015-02-24 22:55:49  2015-04-18 02:47:11              34
# 1   333320  2015-06-07 20:39:50  2015-06-08 01:38:54              16
# 2     1359  2015-01-01 18:52:44  2015-01-01 18:52:45              15
# 3   150084  2015-04-28 21:13:25  2015-05-04 13:54:50              44
# 4   221365  2015-07-21 07:09:52  2015-09-09 18:40:53              39
#
#        device_id source browser sex  age    ip_address  class
# 0  QVPSPJUOCKZAR    SEO  Chrome   M   39  7.327584e+08      0
# 1  EOGFQPIZPYXFZ    Ads  Chrome   F   53  3.503114e+08      0
# 2  YSSKYOSJHPPLJ    SEO   Opera   M   53  2.621474e+09      1
# 3  ATGTXKYKUDUQN    SEO  Safari   M   41  3.840542e+09      0
# 4  NAUITBZFJKHWW    Ads  Safari   M   45  4.155831e+08      0

# %%
df2
# Out:
#         lower_bound_ip_address  upper_bound_ip_address    country
# 0                 1.677722e+07                16777471  Australia
# 1                 1.677747e+07                16777727      China
# 2                 1.677773e+07                16778239      China
# 3                 1.677824e+07                16779263  Australia
# 4                 1.677926e+07                16781311      China
# ...                        ...                     ...        ...
# 138841            3.758092e+09              3758093311  Hong Kong
# 138842            3.758093e+09              3758094335      India
# 138843            3.758095e+09              3758095871      China
# 138844            3.758096e+09              3758096127  Singapore
# 138845            3.758096e+09              3758096383  Australia
#
# [138846 rows x 3 columns]

# %%
df3.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
import EDA
import importlib
importlib.reload(EDA)
# Out:
# <module 'EDA' from '/content/EDA.py'>

# %%
# Check for duplicate rows
EDA.duplicate_check(df1)
# Out:
# 0

# %%
#Correct Data Type
df1=EDA.change_type(df1,'signup_time')
df1=EDA.change_type(df1,'purchase_time')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151112 entries, 0 to 151111
# Data columns (total 11 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   user_id         151112 non-null  int64
#  1   signup_time     151112 non-null  datetime64[ns]
#  2   purchase_time   151112 non-null  datetime64[ns]
#  3   purchase_value  151112 non-null  int64
#  4   device_id       151112 non-null  object
#  5   source          151112 non-null  object
#  6   browser         151112 non-null  object
#  7   sex             151112 non-null  object
#  8   age             151112 non-null  int64
#  9   ip_address      151112 non-null  float64
#  10  class           151112 non-null  int64
# dtypes: datetime64[ns](2), float64(1), int64(4), object(4)
# memory usage: 12.7+ MB

# %% [markdown]
# # Exploratory Data Analysis

# %%
#Univariate analysis - numerical value
EDA.plot_numerical(df1,"purchase_value")
EDA.plot_numerical(df1,"age")
EDA.plot_numerical(df1,"class")

# %%
#Univariate analysis - categorical value
EDA.plot_categorical(df1,"source")
EDA.plot_categorical(df1,"browser")
EDA.plot_categorical(df1,"sex")

# %%
#Bivariate analysis - Correlation Matrix
corr_matrix = EDA.correlation(df1)
corr_matrix
# Out:
#                  user_id  purchase_value       age  ip_address     class
# user_id         1.000000        0.002617  0.000611   -0.003144  0.001945
# purchase_value  0.002617        1.000000  0.002370   -0.000328  0.001011
# age             0.000611        0.002370  1.000000    0.001140  0.006624
# ip_address     -0.003144       -0.000328  0.001140    1.000000 -0.005208
# class           0.001945        0.001011  0.006624   -0.005208  1.000000

# %%
#Scatter Matrix
EDA.scatter_matrix(df1)

# %%
#check Outliers
EDA.box_plot(num_df,'purchase_value')
EDA.box_plot(num_df,'age')

# %%
#show  Outliers
df1=EDA.outlier(df1,'purchase_value')
df1
# Out:
#         user_id         signup_time       purchase_time  purchase_value  \
# 0         22058 2015-02-24 22:55:49 2015-04-18 02:47:11              34
# 1        333320 2015-06-07 20:39:50 2015-06-08 01:38:54              16
# 2          1359 2015-01-01 18:52:44 2015-01-01 18:52:45              15
# 3        150084 2015-04-28 21:13:25 2015-05-04 13:54:50              44
# 4        221365 2015-07-21 07:09:52 2015-09-09 18:40:53              39
# ...         ...                 ...                 ...             ...
# 151107   345170 2015-01-27 03:03:34 2015-03-29 00:30:47              43
# 151108   274471 2015-05-15 17:43:29 2015-05-26 12:24:39              35
# 151109   368416 2015-03-03 23:07:31 2015-05-20 07:07:47              40
# 151110   207709 2015-07-09 20:06:07 2015-09-07 09:34:46              46
# 151111   138208 2015-06-10 07:02:20 2015-07-21 02:03:53              20
#
#             device_id  source browser sex  age    ip_address  class   z_score
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 150247 entries, 0 to 151111
# Data columns (total 12 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   user_id         150247 non-null  int64
#  1   signup_time     150247 non-null  datetime64[ns]
#  2   purchase_time   150247 non-null  datetime64[ns]
#  3   purchase_value  150247 non-null  int64
#  4   device_id       150247 non-null  object
#  5   source          150247 non-null  object
#  6   browser         150247 non-null  object
#  7   sex             150247 non-null  object
#  8   age             150247 non-null  int64
#  9   ip_address      150247 non-null  float64
#  10  class           150247 non-null  int64
#  11  z_score         150247 non-null  float64
# dtypes: datetime64[ns](2), float64(2), int64(4), object(4)
# memory usage: 14.9+ MB

# %% [markdown]
# **Merge Datasets for Geolocation Analysis**

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138846 entries, 0 to 138845
# Data columns (total 3 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   lower_bound_ip_address  138846 non-null  float64
#  1   upper_bound_ip_address  138846 non-null  int64
#  2   country                 138846 non-null  object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 3.2+ MB

# %%
#Convert IP addresses to integer format
df2=EDA.to_int(df2,"lower_bound_ip_address")
df2=EDA.to_int(df2,"upper_bound_ip_address")

# %%
#merge The wo dataframes
interval_index = pd.IntervalIndex.from_arrays(df2['lower_bound_ip_address'], df2['upper_bound_ip_address'], closed='both')
matched_idx = interval_index.get_indexer(df1['ip_address'])
df2_matched = pd.DataFrame(index=df1.index, columns=df2.columns)
df2_matched.loc[matched_idx != -1] = df2.iloc[matched_idx[matched_idx != -1]].values

merged = pd.concat([df1, df2_matched], axis=1)
print(merged)
# Out:
#         user_id         signup_time       purchase_time  purchase_value  \
# 0         22058 2015-02-24 22:55:49 2015-04-18 02:47:11              34
# 1        333320 2015-06-07 20:39:50 2015-06-08 01:38:54              16
# 2          1359 2015-01-01 18:52:44 2015-01-01 18:52:45              15
# 3        150084 2015-04-28 21:13:25 2015-05-04 13:54:50              44
# 4        221365 2015-07-21 07:09:52 2015-09-09 18:40:53              39
# ...         ...                 ...                 ...             ...
# 151107   345170 2015-01-27 03:03:34 2015-03-29 00:30:47              43
# 151108   274471 2015-05-15 17:43:29 2015-05-26 12:24:39              35
# 151109   368416 2015-03-03 23:07:31 2015-05-20 07:07:47              40
# 151110   207709 2015-07-09 20:06:07 2015-09-07 09:34:46              46
# 151111   138208 2015-06-10 07:02:20 2015-07-21 02:03:53              20
#
#             device_id  source browser sex  age    ip_address  class   z_score  \
# ...

# %%
df1
# Out:
#         user_id         signup_time       purchase_time  purchase_value  \
# 0         22058 2015-02-24 22:55:49 2015-04-18 02:47:11              34
# 1        333320 2015-06-07 20:39:50 2015-06-08 01:38:54              16
# 2          1359 2015-01-01 18:52:44 2015-01-01 18:52:45              15
# 3        150084 2015-04-28 21:13:25 2015-05-04 13:54:50              44
# 4        221365 2015-07-21 07:09:52 2015-09-09 18:40:53              39
# ...         ...                 ...                 ...             ...
# 151107   345170 2015-01-27 03:03:34 2015-03-29 00:30:47              43
# 151108   274471 2015-05-15 17:43:29 2015-05-26 12:24:39              35
# 151109   368416 2015-03-03 23:07:31 2015-05-20 07:07:47              40
# 151110   207709 2015-07-09 20:06:07 2015-09-07 09:34:46              46
# 151111   138208 2015-06-10 07:02:20 2015-07-21 02:03:53              20
#
#             device_id  source browser sex  age    ip_address  class   z_score
# ...

# %%
merged
# Out:
#         user_id         signup_time       purchase_time  purchase_value  \
# 0         22058 2015-02-24 22:55:49 2015-04-18 02:47:11              34
# 1        333320 2015-06-07 20:39:50 2015-06-08 01:38:54              16
# 2          1359 2015-01-01 18:52:44 2015-01-01 18:52:45              15
# 3        150084 2015-04-28 21:13:25 2015-05-04 13:54:50              44
# 4        221365 2015-07-21 07:09:52 2015-09-09 18:40:53              39
# ...         ...                 ...                 ...             ...
# 151107   345170 2015-01-27 03:03:34 2015-03-29 00:30:47              43
# 151108   274471 2015-05-15 17:43:29 2015-05-26 12:24:39              35
# 151109   368416 2015-03-03 23:07:31 2015-05-20 07:07:47              40
# 151110   207709 2015-07-09 20:06:07 2015-09-07 09:34:46              46
# 151111   138208 2015-06-10 07:02:20 2015-07-21 02:03:53              20
#
#             device_id  source browser sex  age    ip_address  class   z_score  \
# ...

# %% [markdown]
# **Feature Engineering**

# %%
df['Transaction frequency'] = df.groupby('user_id')['purchase_value'].transform('count')
