# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/Tenx/Week 8/creditcard.csv')

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %% [markdown]
# #EDA

# %%
import EDA
import importlib
importlib.reload(EDA)
# Out:
# <module 'EDA' from '/content/EDA.py'>

# %%
#remove duplicate rows
df=EDA.duplicate_check(df)

# %%
#Univariate analysis - numerical value
EDA.plot_numerical(df,"Amount")
EDA.plot_numerical(df,"Class")

# %%
#Bivariate analysis - Correlation Matrix
corr_matrix = EDA.correlation(df)
corr_matrix['Amount']
# Out:
# Time     -0.010559
# V1       -0.230105
# V2       -0.533428
# V3       -0.212410
# V4        0.099514
# V5       -0.387685
# V6        0.216389
# V7        0.400408
# V8       -0.104662
# V9       -0.044123
# V10      -0.102255
# V11      -0.000015
# V12      -0.009254
# V13       0.005209
# V14       0.034122
# V15      -0.003265
# V16      -0.004488
# V17       0.007730
# V18       0.035775
# V19      -0.055994
# V20       0.340729
# V21       0.108058
# V22      -0.064965
# V23      -0.112833
# V24       0.005055
# V25      -0.047596
# V26      -0.003425
# V27       0.027922
# V28       0.010143
# Amount    1.000000
# Class     0.005777
# Name: Amount, dtype: float64

# %%
df.describe()
# Out:
#                 Time             V1             V2             V3  \
# count  283726.000000  283726.000000  283726.000000  283726.000000
# mean    94811.077600       0.005917      -0.004135       0.001613
# std     47481.047891       1.948026       1.646703       1.508682
# min         0.000000     -56.407510     -72.715728     -48.325589
# 25%     54204.750000      -0.915951      -0.600321      -0.889682
# 50%     84692.500000       0.020384       0.063949       0.179963
# 75%    139298.000000       1.316068       0.800283       1.026960
# max    172792.000000       2.454930      22.057729       9.382558
#
#                   V4             V5             V6             V7  \
# count  283726.000000  283726.000000  283726.000000  283726.000000
# mean       -0.002966       0.001828      -0.001139       0.001801
# std         1.414184       1.377008       1.331931       1.227664
# min        -5.683171    -113.743307     -26.160506     -43.557242
# ...

# %%
#check Outliers
num_df = df.select_dtypes(include=['int64', 'float64'])
EDA.box_plot(num_df,'Amount')

# %%
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
#remove  Outliers
df=EDA.remove_outliers(df,'Amount')
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V22       V23  \
# ...

# %%
# check distribution
print(df['Class'].value_counts(normalize=True))
# Out:
# Class
# 0    0.998348
# 1    0.001652
# Name: proportion, dtype: float64

# %%
#train and test data
xtrain,xtest,ytrain, ytest=EDA.split_data(df)

# %%
from imblearn.combine import SMOTEENN
from collections import Counter

# Create SMOTEENN object
smote_enn = SMOTEENN(random_state=42)

# Apply only on training data
X_train_res, y_train_res = smote_enn.fit_resample(xtrain, ytrain)

# Check new class distribution
print("Original:", Counter(ytrain))
print("Resampled:", Counter(y_train_res))
# Out:
# Original: Counter({0: 223360, 1: 370})
# Resampled: Counter({1: 215122, 0: 206285})

# %%
xtrain,xtest=EDA.scale_data(X_train_res,xtest)

# %% [markdown]
# # Model Building and Training

# %%
#Logistic regression
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(max_iter=10000, random_state=42)
lr.fit(xtrain,y_train_res)
y_pred = lr.predict(xtrain)
y_proba = lr.predict_proba(xtrain)[:,1]

# %%
# Evaluate model
from sklearn.metrics import f1_score, classification_report, confusion_matrix, precision_recall_curve, auc

# F1 score
print("F1 score (LR):", f1_score(y_train_res, y_pred))

# Confusion matrix
print("Confusion matrix (LR):\n", confusion_matrix(y_train_res, y_pred))

# Precision-Recall AUC
precision, recall, _ = precision_recall_curve(y_train_res, y_proba)
pr_auc = auc(recall, precision)
print("PR AUC (LR):", pr_auc)
# Out:
# F1 score (LR): 0.9843613290641896
# Confusion matrix (LR):
#  [[204916   1369]
#  [  5298 209824]]
# PR AUC (LR): 0.9984468762449151

# %%
#Random Forest Classifier
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=8, random_state=42)
rf.fit(xtrain, y_train_res)
y_pred_rf = rf.predict(xtrain)
y_proba_rf = rf.predict_proba(xtrain)[:,1]

# %%
# F1 score
print("F1 score:", f1_score(y_train_res, y_pred_rf))

# Confusion matrix
print("Confusion matrix:\n", confusion_matrix(y_train_res, y_pred_rf))

# Precision-Recall AUC
precision, recall, _ = precision_recall_curve(y_train_res, y_proba_rf)
pr_auc = auc(recall, precision)
print("PR AUC:", pr_auc)
# Out:
# F1 score: 0.9999883787684749
# Confusion matrix:
#  [[206281      4]
#  [     1 215121]]
# PR AUC: 0.9999999990924264

# %%
#XG Boost
from xgboost import XGBClassifier
xgb = XGBClassifier(n_estimators=20, max_depth=18, learning_rate=0.1, random_state=42, subsample=0.6)
xgb.fit(xtrain, y_train_res)
y_pred_xgb = xgb.predict(xtrain)
y_proba_xgb = xgb.predict_proba(xtrain)[:,1]

# %%
# F1 score
print("F1 score:", f1_score(y_train_res, y_pred_xgb))

# Confusion matrix
print("Confusion matrix:\n", confusion_matrix(y_train_res, y_pred_xgb))

# Precision-Recall AUC
precision, recall, _ = precision_recall_curve(y_train_res, y_proba_xgb)
pr_auc = auc(recall, precision)
print("PR AUC:", pr_auc)
# Out:
# F1 score: 0.9996095910466213
# Confusion matrix:
#  [[206164    121]
#  [    47 215075]]
# PR AUC: 0.999913216734946

# %%
#evaluate on test data
yt_pred = lr.predict(xtest)
yt_proba = lr.predict_proba(xtest)[:,1]
yt_pred_rf = rf.predict(xtest)
yt_proba_rf = rf.predict_proba(xtest)[:,1]
yt_pred_xgb = xgb.predict(xtest)
yt_proba_xgb = xgb.predict_proba(xtest)[:,1]

# F1 score
print("F1 score (Log Reg):", f1_score(ytest, yt_pred))
print("F1 score (Random Forest):", f1_score(ytest, yt_pred_rf))
print("F1 score (XGBoost):", f1_score(ytest, yt_pred_xgb))
# Out:
# F1 score (Log Reg): 0.2851851851851852
# F1 score (Random Forest): 0.8045977011494253
# F1 score (XGBoost): 0.6431718061674009

# %%
# Confusion matrix
print("Confusion matrix:\n (LR)", confusion_matrix(ytest, yt_pred))
print("Confusion matrix:\n (RF)", confusion_matrix(ytest, yt_pred_rf))
print("Confusion matrix:\n (XB)", confusion_matrix(ytest, yt_pred_xgb))
# Out:
# Confusion matrix:
#  (LR) [[55470   371]
#  [   15    77]]
# Confusion matrix:
#  (RF) [[55829    12]
#  [   22    70]]
# Confusion matrix:
#  (XB) [[55779    62]
#  [   19    73]]

# %%
# Precision-Recall AUC
precision, recall, _ = precision_recall_curve(ytest, yt_proba)
pr_auc = auc(recall, precision)
print("PR AUC (LR):", pr_auc)
precision, recall, _ = precision_recall_curve(ytest, yt_proba_rf)
pr_auc = auc(recall, precision)
print("PR AUC (RF):", pr_auc)
precision, recall, _ = precision_recall_curve(ytest, yt_proba_xgb)
pr_auc = auc(recall, precision)
print("PR AUC (XG):", pr_auc)
# Out:
# PR AUC (LR): 0.7275772149724128
# PR AUC (RF): 0.7768607190842921
# PR AUC (XG): 0.7398431490566324

# %% [markdown]
# # Model Expainability

# %%
xtrain=X_train_res

# %%
#Logistic Regression
import pandas as pd
import numpy as np
coef = lr.coef_[0]
feature_importance = pd.DataFrame({"Feature": xtrain.columns,"Coefficient": coef,"AbsCoefficient": np.abs(coef)}).sort_values(by="AbsCoefficient", ascending=False)
print(feature_importance)
# Out:
#     Feature  Coefficient  AbsCoefficient
# 17      V17   -11.640643       11.640643
# 14      V14   -11.137302       11.137302
# 12      V12    -7.208439        7.208439
# 10      V10    -5.975577        5.975577
# 1        V1     5.380467        5.380467
# 16      V16    -4.209356        4.209356
# 8        V8    -3.311813        3.311813
# 4        V4     3.310011        3.310011
# 11      V11     2.599677        2.599677
# 9        V9    -1.943525        1.943525
# 5        V5     1.859540        1.859540
# 3        V3     1.423825        1.423825
# 27      V27     1.285573        1.285573
# 18      V18    -1.268337        1.268337
# 2        V2    -0.762474        0.762474
# 20      V20    -0.705351        0.705351
# 21      V21     0.688060        0.688060
# 0      Time    -0.605716        0.605716
# 7        V7    -0.555776        0.555776
# 28      V28     0.533089        0.533089
# 22      V22     0.498516        0.498516
# 19      V19     0.430331        0.430331
# ...

# %%
# XGB Boost - Create SHAP explainer
import shap
import matplotlib.pyplot as plt

# Create SHAP explainer
explainer = shap.Explainer(xgb,xtrain)

# Compute SHAP values
shap_values = explainer(xtrain)

# Convert SHAP values to DataFrame
shap_df = pd.DataFrame(shap_values.values, columns=xtrain.columns)

# Map one-hot encoded columns back to original feature
group_map = {col: col.split("_")[0] for col in shap_df.columns}

# Aggregate SHAP values by original feature
shap_grouped_df = shap_df.T.groupby(group_map).sum().T

# Wrap back into Explanation object
shap_grouped_exp = shap.Explanation(values=shap_grouped_df.values, base_values=shap_values.base_values, data=shap_grouped_df.values,feature_names=shap_grouped_df.columns)

# Plot grouped summary
shap.plots.bar(shap_grouped_exp)
# Out:
# 100%|===================| 420898/421407 [10:55<00:00]

# %%
# Convert grouped SHAP DataFrame back into Explanation object
shap_grouped_exp = shap.Explanation(values=shap_grouped_df.values,base_values=shap_values.base_values,
    data=shap_grouped_df.values, feature_names=shap_grouped_df.columns)

# Beeswarm summary plot
shap.plots.beeswarm(shap_grouped_exp)

# %%
# Pick a row (e.g., first test sample)
i = 0
shap.initjs()

shap.force_plot(
    shap_grouped_exp.base_values[i],
    shap_grouped_exp.values[i],
    shap_grouped_exp.data[i],
    feature_names=shap_grouped_exp.feature_names)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...
